# %% [markdown]
# # Data Cleaning

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# importing libraries

# %%
df=pd.read_csv('t20.csv') #reading csv files

# %%
df
# Out:
#       Unnamed: 0                  Player       Span  Mat Inns  NO  Runs   HS  \
# 0              0         V Kohli (INDIA)  2010-2019   75   70  20  2633  94*
# 1              1       RG Sharma (INDIA)  2007-2019  104   96  14  2633  118
# 2              2         MJ Guptill (NZ)  2009-2019   83   80   7  2436  105
# 3              3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263   75
# 4              4        BB McCullum (NZ)  2005-2015   71   70  10  2140  123
# ...          ...                     ...        ...  ...  ...  ..   ...  ...
# 2001           1   SG Whittingham (SCOT)  2018-2018    3    -   -     -    -
# 2002           2        LJ Woodcock (NZ)  2010-2011    3    -   -     -    -
# 2003           3        Zamir Khan (AFG)  2012-2012    1    -   -     -    -
# 2004           4          S Zargar (Mex)  2019-2019    1    -   -     -    -
# 2005           5      Ziaur Rahman (AFG)  2019-2019    1    -   -     -    -
#
# ...

# %%
df.shape #to get number of rows and columns
# Out:
# (2006, 17)

# %%
df = df.drop(['Unnamed: 0', 'Unnamed: 15'],axis=1)
df  # to drop unnecessary columns
# Out:
#                       Player       Span  Mat Inns  NO  Runs   HS    Ave    BF  \
# 0            V Kohli (INDIA)  2010-2019   75   70  20  2633  94*  52.66  1907
# 1          RG Sharma (INDIA)  2007-2019  104   96  14  2633  118   32.1  1905
# 2            MJ Guptill (NZ)  2009-2019   83   80   7  2436  105  33.36  1810
# 3     Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263   75  30.58  1824
# 4           BB McCullum (NZ)  2005-2015   71   70  10  2140  123  35.66  1571
# ...                      ...        ...  ...  ...  ..   ...  ...    ...   ...
# 2001   SG Whittingham (SCOT)  2018-2018    3    -   -     -    -      -     -
# 2002        LJ Woodcock (NZ)  2010-2011    3    -   -     -    -      -     -
# 2003        Zamir Khan (AFG)  2012-2012    1    -   -     -    -      -     -
# 2004          S Zargar (Mex)  2019-2019    1    -   -     -    -      -     -
# 2005      Ziaur Rahman (AFG)  2019-2019    1    -   -     -    -      -     -
#
# ...

# %%
# axis 1 is to tell that we want to apply function on columns

# %%
for col in df.columns:
    print(col) # to print only column names in dataset
# Out:
# Player
# Span
# Mat
# Inns
# NO
# Runs
# HS
# Ave
# BF
# SR
# 100
# 50
# 0
# 4s
# 6s

# %%
print(df.keys()) #to get axis info
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0', '4s', '6s'],
#       dtype='object')

# %%
df.isna() #to check if there is any unnecessary value
# Out:
#       Player   Span    Mat   Inns     NO   Runs     HS    Ave     BF     SR  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2001   False  False  False  False  False  False  False  False  False  False
# 2002   False  False  False  False  False  False  False  False  False  False
# 2003   False  False  False  False  False  False  False  False  False  False
# 2004   False  False  False  False  False  False  False  False  False  False
# 2005   False  False  False  False  False  False  False  False  False  False
#
#         100     50      0     4s     6s
# ...

# %%
df.isnull() #to check if there is any null value
# Out:
#       Player   Span    Mat   Inns     NO   Runs     HS    Ave     BF     SR  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2001   False  False  False  False  False  False  False  False  False  False
# 2002   False  False  False  False  False  False  False  False  False  False
# 2003   False  False  False  False  False  False  False  False  False  False
# 2004   False  False  False  False  False  False  False  False  False  False
# 2005   False  False  False  False  False  False  False  False  False  False
#
#         100     50      0     4s     6s
# ...

# %%
df.isnull().sum() #to give sum of null values or to check how many null values are there
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Ave       0
# BF        0
# SR        0
# 100       0
# 50        0
# 0         0
# 4s        0
# 6s        0
# dtype: int64

# %%
df.head(10) # to read only first 10 rows
# Out:
#                    Player       Span  Mat Inns  NO  Runs    HS    Ave    BF  \
# 0         V Kohli (INDIA)  2010-2019   75   70  20  2633   94*  52.66  1907
# 1       RG Sharma (INDIA)  2007-2019  104   96  14  2633   118   32.1  1905
# 2         MJ Guptill (NZ)  2009-2019   83   80   7  2436   105  33.36  1810
# 3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263    75  30.58  1824
# 4        BB McCullum (NZ)  2005-2015   71   70  10  2140   123  35.66  1571
# 5         DA Warner (AUS)  2009-2019   76   76   8  2079  100*  30.57  1476
# 6        EJG Morgan (ENG)  2009-2019   86   84  17  2002    91  29.88  1475
# 7  Mohammad Shahzad (AFG)  2010-2018   65   65   3  1936  118*  31.22  1436
# 8          JP Duminy (SA)  2007-2019   81   75  25  1934   96*  38.68  1532
# 9       PR Stirling (IRE)  2009-2019   72   71   6  1929    91  29.67  1401
#
#        SR 100  50  0   4s   6s
# 0  138.07   0  24  2  247   71
# 1  138.21   4  19  6  234  120
# 2  134.58   2  15  2  215  113
# ...

# %%
df.dtypes # to check types of columns
# Out:
# Player    object
# Span      object
# Mat        int64
# Inns      object
# NO        object
# Runs      object
# HS        object
# Ave       object
# BF        object
# SR        object
# 100       object
# 50        object
# 0         object
# 4s        object
# 6s        object
# dtype: object

# %%
df.describe() #to get description of dataset
# Out:
#                Mat
# count  2006.000000
# mean     11.231805
# std      14.923332
# min       1.000000
# 25%       3.000000
# 50%       5.000000
# 75%      13.000000
# max     111.000000

# %%
df.describe(include="O") #to select categorial columns and the ones with numeric value
# Out:
#                  Player       Span  Inns    NO  Runs    HS   Ave    BF    SR  \
# count              2006       2006  2006  2006  2006  2006  2006  2006  2006
# unique             2006        115    77    26   453   219   711   413  1064
# top     V Kohli (INDIA)  2019-2019     1     0     -     -     -     -     -
# freq                  1        876   328   705   152   152   328   152   175
#
#          100    50     0    4s    6s
# count   2006  2006  2006  2006  2006
# unique     6    19    12   130    74
# top        0     0     0     0     0
# freq    1812  1493  1034   506   851

# %%
df.Mat.value_counts() # Return a Series containing counts of unique rows in the DataFrame
# Out:
# 3      247
# 2      235
# 4      212
# 1      207
# 5      124
#       ...
# 55       1
# 59       1
# 69       1
# 99       1
# 104      1
# Name: Mat, Length: 87, dtype: int64

# %% [markdown]
# # Data Integration

# %%
df1 = pd.read_csv('BG.csv')
df2 = pd.read_csv('GG.csv')
# reading both the files

# %%
df1
# Out:
#    Unnamed: 0   ID     Boy Groups   Debut  Active Years
# 0         NaN  NaN            NaN     NaN           NaN
# 1         0.0  1.0        MonstaX  2015.0           7.0
# 2         1.0  2.0            Exo  2012.0          10.0
# 3         2.0  3.0     Stray Kids  2018.0           4.0
# 4         3.0  4.0  One Direction  2010.0           6.0

# %%
df2
# Out:
#    Unnamed: 0   ID Girl Group   Debut  Active Years
# 0         NaN  NaN        NaN     NaN           NaN
# 1         0.0  1.0  Blackpink  2016.0           6.0
# 2         1.0  2.0       Itzy  2019.0           3.0
# 3         2.0  3.0      Twice  2015.0           7.0
# 4         3.0  4.0    Mamamoo  2014.0           8.0

# %%
df1 =pd.read_csv('BG.csv')
X = df1.drop('Active Years',axis=1)
X
# dropping columns from table or file
# Out:
#    Unnamed: 0   ID     Boy Groups   Debut
# 0         NaN  NaN            NaN     NaN
# 1         0.0  1.0        MonstaX  2015.0
# 2         1.0  2.0            Exo  2012.0
# 3         2.0  3.0     Stray Kids  2018.0
# 4         3.0  4.0  One Direction  2010.0

# %%
df2 =pd.read_csv('GG.csv')
Y = df1.drop('Active Years',axis=1)
Y
#dropping columns from table or file
# Out:
#    Unnamed: 0   ID     Boy Groups   Debut
# 0         NaN  NaN            NaN     NaN
# 1         0.0  1.0        MonstaX  2015.0
# 2         1.0  2.0            Exo  2012.0
# 3         2.0  3.0     Stray Kids  2018.0
# 4         3.0  4.0  One Direction  2010.0

# %%
data = pd.merge(X,Y,on='ID')
print(data)
#merging or adding datasets by giving ID as axis
# Out:
#    Unnamed: 0_x   ID   Boy Groups_x  Debut_x  Unnamed: 0_y   Boy Groups_y  \
# 0           NaN  NaN            NaN      NaN           NaN            NaN
# 1           0.0  1.0        MonstaX   2015.0           0.0        MonstaX
# 2           1.0  2.0            Exo   2012.0           1.0            Exo
# 3           2.0  3.0     Stray Kids   2018.0           2.0     Stray Kids
# 4           3.0  4.0  One Direction   2010.0           3.0  One Direction
#
#    Debut_y
# 0      NaN
# 1   2015.0
# 2   2012.0
# 3   2018.0
# 4   2010.0

# %%
df2 = pd.read_csv('GG.csv')
W = df2.drop(0).head()
W
#Dropping rows
# Out:
#    Unnamed: 0   ID Girl Group   Debut  Active Years
# 1         0.0  1.0  Blackpink  2016.0           6.0
# 2         1.0  2.0       Itzy  2019.0           3.0
# 3         2.0  3.0      Twice  2015.0           7.0
# 4         3.0  4.0    Mamamoo  2014.0           8.0

# %% [markdown]
# # Data Reduction

# %%
df2 = pd.read_csv('BG.csv')
D = df2.drop(0).head()
D
#Dropping Rows
# Out:
#    Unnamed: 0   ID     Boy Groups   Debut  Active Years
# 1         0.0  1.0        MonstaX  2015.0           7.0
# 2         1.0  2.0            Exo  2012.0          10.0
# 3         2.0  3.0     Stray Kids  2018.0           4.0
# 4         3.0  4.0  One Direction  2010.0           6.0

# %%
Data = pd.merge(W,D,on='ID')
Data
#Merging the datasets
# Out:
#    Unnamed: 0_x   ID Girl Group  Debut_x  Active Years_x  Unnamed: 0_y  \
# 0           0.0  1.0  Blackpink   2016.0             6.0           0.0
# 1           1.0  2.0       Itzy   2019.0             3.0           1.0
# 2           2.0  3.0      Twice   2015.0             7.0           2.0
# 3           3.0  4.0    Mamamoo   2014.0             8.0           3.0
#
#       Boy Groups  Debut_y  Active Years_y
# 0        MonstaX   2015.0             7.0
# 1            Exo   2012.0            10.0
# 2     Stray Kids   2018.0             4.0
# 3  One Direction   2010.0             6.0

# %% [markdown]
# # Data Transformation

# %%
sns.countplot(df['Player'],label="count")
#Visualie this count
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Player', ylabel='count'>

# %%
# select numeric values
numeric_vars = ['Mat']
# create histogram for each numeriv variable
fig = plt.figure(figsize=(25,15))
for i in range(len(numeric_vars)):
    var=numeric_vars[i]
    sub=fig.add_subplot(2,5,i+1)
    sub.set_xlabel(var)
    df[var].plot(kind='hist')

# %%
numeric = ['Mat']
# # create histogram for each numeriv variable
fig = plt.figure(figsize=(25,15))
for i in range(len(numeric_vars)):
    var=numeric_vars[i]
    sub=fig.add_subplot(2,5,i+1)
    sub.set_xlabel(var)
    df[var].plot(kind='hist')
